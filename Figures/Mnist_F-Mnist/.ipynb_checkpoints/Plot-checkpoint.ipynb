# %%
import train_mnist
import mnist_net

import train_fashion_mnist
import fashion_mnist_net

# %%
# %run train_mnist.py --fname models/plt_mnist.pth --attack "pgd" --attack-iters 40 --epsilon 0.15 --alpha 0.1875

# %%
# %run train_fashion_mnist.py --fname models/plt1_f_mnist.pth --attack "pgd" --attack-iters 40 --epsilon 0.15 --alpha 0.1875
